# %%
import seaborn as sns
import pandas as pd

# %%
df = pd.read_csv('../collection/out/sold.csv')

# %%
df.head()
# Out:
#                address  floor                  area    rent       price  \
# 0        Ringvägen 106    1.0                Sofia,  1948.0   5400000.0
# 1  Bergsunds Strand 38    3.0              Högalid,  2271.0   3600000.0
# 2      Heimdalsgatan 3    4.0  Vasastan - Odenplan,  4561.0  11500000.0
# 3      Tegnérgatan 55A    6.0             Vasastan,  2089.0   4120000.0
# 4     Fridhemsgatan 33    1.0          Kungsholmen,  3521.0   6300000.0
#
#          date    kr_sqm  change    sqm  rooms
# 0  2020-03-20   84375.0    14.0   64.0    2.0
# 1  2020-03-20   75000.0     9.0   48.0    2.0
# 2  2020-03-20  111650.0    15.0  103.0    5.0
# 3  2020-03-20  137333.0    33.0   30.0    2.0
# 4  2020-03-20   92647.0    11.0   68.0    3.0

# %%
sns.lmplot('sqm', 'price', df, ci=100)

# %%
from sklearn.model_selection import train_test_split
X = df[['floor', 'sqm', 'rent', 'rooms']]
y = df.price
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
import pickle
pickle.dump(model, open('sthml.pkl', 'wb'))

# %%
from yellowbrick.regressor import residuals_plot
residuals_plot(model, X_train, y_train, X_test, y_test)
# Out:
# 0.8716143996295748
# ResidualsPlot(ax=<matplotlib.axes._subplots.AxesSubplot object at 0x000001878FCE4E20>,
#               hist=True, is_fitted='auto', line_color=None, model=None,
#               test_alpha=None, test_color=None, train_alpha=None,
#               train_color=None)

# %%
import pickle
pickle.dump(model, open('out/linear-regession.pkl', 'wb'))
